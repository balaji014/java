# %% [markdown]
# # Python Learning Notebook
# This is my first notebook in VS Code!

# %%
print("Hello, Jupyter!")
# Out:
# Failed to start the Kernel.
#
# AttributeError: module 'numbers' has no attribute 'Number'. Did you mean: 'numbers'?.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
